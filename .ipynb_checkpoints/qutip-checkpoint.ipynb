# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *
from scipy import *

delta  = 0.2 * 2*pi; eps0  = 1.0 * 2*pi
A      = 0.5 * 2*pi; 
tlist  = np.linspace(0.0, 10 * T, 101)
psi0   = basis(2,0)
omega  = 1.0 * 2*np.pi; A_vec = np.linspace(0, 10, 1001) * omega;
T      = (2*pi)/omega
psi0   = basis(2,0)

q_energies = np.zeros((len(A_vec), 2))

H0 = - delta/2.0 * sigmax() - eps0/2.0 * sigmaz()
H1 = A/2.0 * sigmaz()
args = {'w': omega}
w = omega
H = [H0, [H1, lambda t,args: np.sin(args['w'] * t)]]

for idx, A in enumerate(A_vec):
    H1 = A/2.0 * sigmax()
    #H = [H0, [H1, lambda t, w: np.sin(w*t)]]
    H = [H0, [H1, lambda t,args: np.sin(args['w'] * t)]]
    f_modes, f_energies = floquet_modes(H, T, args, True)
    q_energies[idx,:] = f_energies

plt.plot(A_vec/omega,q_energies)
plt.show()

# %% [markdown]
# ### use Qutip on mean field dynamics
#
# check T. Mori's paper

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *
from scipy import *
import math

N =4; h = 25.0; h0 = 0.1;    
q = np.linspace(-0.5, 0.5, N)
cosp = np.zeros((N,N)) + (1j) * np.zeros((N,N))
cosp_init = np.zeros((N,N)) + (1j) * np.zeros((N,N))
omega = 1.0 * 2 * np.pi/4; A_vec = np.linspace(0, 10, 100) * omega;
T = (2*np.pi)/omega
tlist  = np.linspace(0.0, 10 * T, 101)
args = {'w': omega}

cospinit = 0.0
for k in np.arange(N):
    for m in np.arange(N):
        for l in np.arange(N+1):
            for j in np.arange(l+1):
                cospinit = cospinit + np.array([pow((-1),(l+j))/math.factorial(2 * l)* math.comb(l,j)])
        cosp[k,m] = cospinit
        cospinit = 0.0
                                                
psi0 = basis(N,0)
H0 = Qobj(-2*q*q)
H1 = Qobj(- np.sqrt(1.0 - 4.0 * q * q) * cosp)


for idw, wv in enumerate(w_vec):
    H = [H0,[H1,lambda t,h0: h0+h*np.cos(args[w] * t)]]
    f_modes, f_energies = floquet_modes(H, T, args, True)
# Out:
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-86ad9cf6508d> in <module>
#      29 for idw, w in enumerate(omegas):
#      30     H = [H0,[H1,lambda t: h0+h*np.cos(w * t)]]
# ---> 31     f_modes, f_energies = floquet_modes(H, tlist, args, True)
#
# ~/.local/lib/python3.8/site-packages/qutip/floquet.py in floquet_modes(H, T, args, sort, U)
#     100     if U is None:
#     101         # get the unitary propagator
# --> 102         U = propagator(H, T, [], args)
#     103
#     104     # find the eigenstates for the propagator
#
# ~/.local/lib/python3.8/site-packages/qutip/propagator.py in propagator(H, t, c_op_list, args, options, unitary_mode, parallel, progress_bar, _safe_mode, **kwargs)
#     127
#     128     if _safe_mode:
# --> 129         _solver_safety_check(H, None, c_ops=c_op_list, e_ops=[], args=args)
#     130
#     131     td_type = _td_format_check(H, c_op_list, solver='me')
#
# ~/.local/lib/python3.8/site-packages/qutip/solver.py in _solver_safety_check(H, state, c_ops, e_ops, args)
#     912             Htype = H[0](0,args).type
#     913         else:
# --> 914             raise Exception('Invalid td-list element.')
#     915         # Check all operators in list
#     916         for ii in range(len(H)):
#
# Exception: Invalid td-list element.

# %%
print(psi0)
# Out:
# Quantum object: dims = [[4], [1]], shape = (4, 1), type = ket
# Qobj data =
# [[1.]
#  [0.]
#  [0.]
#  [0.]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *
from scipy import *
import math

N =4; h = 25.0; h0 = 0.1;    
q = np.linspace(-0.5, 0.5, N)
cosp = np.zeros((N,N)) + (1j) * np.zeros((N,N))
cosp_init = np.zeros((N,N)) + (1j) * np.zeros((N,N))
omega = 1.0 * 2 * np.pi; w_vec = np.linspace(0, 10, 100) * omega;
T = (2*np.pi)/omega
tlist  = np.linspace(0.0, 10 * T, 101)
args = {'w': omega}

cospinit = 0.0
for k in np.arange(N):
    for m in np.arange(N):
        for l in np.arange(N+1):
            for j in np.arange(l+1):
                cospinit = cospinit + np.array([pow((-1),(l+j))/math.factorial(2 * l)* math.comb(l,j)])
        cosp[k,m] = cospinit
        cospinit = 0.0
                                                
psi0 = basis(N,0)
H0 = Qobj(-2*q*q)
H1 = Qobj(- np.sqrt(1.0 - 4.0 * q * q) * cosp)

for idw, wv in enumerate(A_vec):
    H = [H0,[H1,lambda t,h0: h0+h*np.cos(args[w] * t)]]
    f_modes, f_energies = floquet_modes(H, T, args, True)
# Out:
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# [1.]
# [0.5]
# [1.]
# [1.04166667]
# [0.95833333]
# [1.]
# [0.99861111]
# [1.00277778]
# [0.99861111]
# [1.]
# [1.0000248]
# [0.9999256]
# [1.0000744]
# [0.9999752]
# [1.]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-eae743742f5a> in <module>
#      32 for idw, w in enumerate(w_vec):
#      33     H = [H0,[H1,lambda t,h0: h0+h*np.cos(w * t)]]
# ---> 34     f_modes, f_energies = floquet_modes(H, T, args, True)
#
# ~/.local/lib/python3.8/site-packages/qutip/floquet.py in floquet_modes(H, T, args, sort, U)
#     100     if U is None:
#     101         # get the unitary propagator
# --> 102         U = propagator(H, T, [], args)
#     103
#     104     # find the eigenstates for the propagator
#
# ~/.local/lib/python3.8/site-packages/qutip/propagator.py in propagator(H, t, c_op_list, args, options, unitary_mode, parallel, progress_bar, _safe_mode, **kwargs)
#     127
#     128     if _safe_mode:
# --> 129         _solver_safety_check(H, None, c_ops=c_op_list, e_ops=[], args=args)
#     130
#     131     td_type = _td_format_check(H, c_op_list, solver='me')
#
# ~/.local/lib/python3.8/site-packages/qutip/solver.py in _solver_safety_check(H, state, c_ops, e_ops, args)
#     912             Htype = H[0](0,args).type
#     913         else:
# --> 914             raise Exception('Invalid td-list element.')
#     915         # Check all operators in list
#     916         for ii in range(len(H)):
#
# Exception: Invalid td-list element.

# %%
import numpy as np
import matplotlib.pyplot as plt
from qutip import *
from scipy import *
import math

N =4    
q = np.linspace(-0.5, 0.5, N)
cosp = np.zeros((N,N)) + (1j) * np.zeros((N,N))
cosp_init = np.zeros((N,N)) + (1j) * np.zeros((N,N))
omega = 1.0 * 2 * np.pi 
h = np.linspace(0, 10, 100)
h0 = 0.1
T = (2*np.pi)/omega
tlist  = np.linspace(0.0, 10 * T, 101)
args = {'w': omega}

cospinit = 0.0
for k in np.arange(N):
    for m in np.arange(N):
        for l in np.arange(N+1):
            for j in np.arange(l+1):
                cospinit = cospinit + np.array([pow((-1),(l+j))/math.factorial(2 * l)* math.comb(l,j)])
        cosp[k,m] = cospinit
        cospinit = 0.0
                                                
psi0 = np.zeros(N)
psi0[0] = 1.0
H0 = Qobj(-2*q*q)
H1 = Qobj(- np.sqrt(1.0 - 4.0 * q * q) * cosp)

for idw, wv in enumerate(h):
    H = [H0,[H1,lambda t,h0: h0+h*np.cos(args[w] * t)]]
    f_modes, f_energies = floquet_modes(H, T, args, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7353827c2932> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from qutip import *
#       4 from scipy import *
#       5 import math
#
# ~/gitrepos/floquet_theory/qutip.py in <module>
#      23         cospinit = 0.0
#      24
# ---> 25 psi0 = basis(N,0)
#      26 H0 = Qobj(-2*q*q)
#      27 H1 = Qobj(- np.sqrt(1.0 - 4.0 * q * q) * cosp)
#
# NameError: name 'basis' is not defined

# %%
print(psi0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5daea079cfb8> in <module>
# ----> 1 print(psi0)
#
# NameError: name 'psi0' is not defined
